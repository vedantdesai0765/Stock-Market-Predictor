# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
df = pd.read_csv("../data/processed/TCS_features.csv")

print(df.head())

# %%
features = [
    'Close',
    'SMA_20',
    'SMA_50',
    'EMA_20',
    'RSI',
    'MACD',
    'Daily_Return'
]

data = df[features]

print(data.head())

# %%
scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(data)

print(scaled_data.shape)

# %%
sequence_length = 30

X = []
y = []

for i in range(sequence_length, len(scaled_data)):
    X.append(scaled_data[i-sequence_length:i])
    y.append(scaled_data[i][0])

X = np.array(X)
y = np.array(y)

print("X shape:", X.shape)
print("y shape:", y.shape)

# %%
split = int(len(X) * 0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)

# %%
model = Sequential()

model.add(
    LSTM(
        units=64,
        return_sequences=True,
        input_shape=(X_train.shape[1], X_train.shape[2])
    )
)

model.add(Dropout(0.2))

model.add(LSTM(units=64))

model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(
    optimizer='adam',
    loss='mean_squared_error'
)

model.summary()

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test)
)

# %%
predictions = model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, predictions))

print("RMSE:", rmse)

# %%
plt.figure(figsize=(12,6))

plt.plot(y_test, label='Actual Price')
plt.plot(predictions, label='Predicted Price')

plt.title("LSTM Stock Price Prediction - TCS")
plt.xlabel("Time")
plt.ylabel("Scaled Stock Price")

plt.legend()

plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test, predictions))

print("LSTM RMSE:", rmse)

# %%
from tensorflow.keras.layers import Dense, LSTM, GRU, Dropout
gru_model = Sequential()

gru_model.add(
    GRU(
        units=64,
        return_sequences=True,
        input_shape=(X_train.shape[1], X_train.shape[2])
    )
)

gru_model.add(Dropout(0.2))

gru_model.add(GRU(units=64))

gru_model.add(Dropout(0.2))

gru_model.add(Dense(1))

gru_model.compile(
    optimizer='adam',
    loss='mean_squared_error'
)

gru_model.summary()

# %%
gru_history = gru_model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test)
)

# %%
gru_predictions = gru_model.predict(X_test)

gru_rmse = np.sqrt(
    mean_squared_error(y_test, gru_predictions)
)

print("GRU RMSE:", gru_rmse)

# %%
plt.figure(figsize=(12,6))

plt.plot(y_test, label='Actual Price')
plt.plot(gru_predictions, label='GRU Predicted Price')

plt.title("GRU Stock Price Prediction - TCS")

plt.xlabel("Time")
plt.ylabel("Scaled Stock Price")

plt.legend()

plt.show()

# %%
print("Random Forest Accuracy: 0.53")
print("LSTM RMSE:", rmse)
print("GRU RMSE:", gru_rmse)

# %%
news_df = pd.read_csv("../data/raw/Combined_News_DJIA.csv")

print(news_df.head())

print(news_df.columns)
